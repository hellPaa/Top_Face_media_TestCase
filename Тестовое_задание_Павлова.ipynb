# %% [markdown]
# <a href="https://colab.research.google.com/github/hellPaa/Top_Face_media_TestCase/blob/main/%D0%A2%D0%B5%D1%81%D1%82%D0%BE%D0%B2%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%9F%D0%B0%D0%B2%D0%BB%D0%BE%D0%B2%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Тестовое задание на позицию начинающего аналитика данных в Topface Media
#
# Павлова Е.А.

# %% [markdown]
# ## **Вопросы:**

# %% [markdown]
# 1) Я оцениваю свои навыки в Python на 7 из 10, потому что у меня есть прочное понимание основных концепций и синтаксиса Python. Кроме того, я имею опыт в области анализа данных, где использовала Python для обработки и визуализации данных. Однако я также осознаю, что всегда есть место для улучшения, особенно в области оптимизации кода и более глубокого понимания некоторых библиотек, используемых в анализе данных, таких как pandas и numpy. Я активно работаю над этими областями, изучая новые ресурсы и участвуя в онлайн-курсах. Я готова быстро учиться и адаптироваться к новым задачам, в том числе и в области анализа данных.
# Кроме того, в рамках анализа данных, я работала над проектами, включающими обработку больших объемов информации, построение информативных графиков.

# %% [markdown]
# 2) Я оцениваю свои навыки в Google Sheets на 5 из 10, потому что у меня есть базовое понимание этого инструмента. Я способна создавать таблицы, вводить данные и выполнять базовые вычисления. Однако, я осознаю, что у меня ограниченный опыт в выполнении более сложных задач, таких как анализ данных или создание сложных формул. Мои навыки в автоматизации процессов в Google Sheets также ограничены. Я готова улучшить свои навыки и изучить более продвинутые функции этого инструмента, так как я верю, что это поможет мне быть более эффективной и полезной для команды.

# %% [markdown]
# ## **Задачи на логику**

# %% [markdown]
# **1)**
#
# Начальный дневной бюджет составлял 40 долларов.
# Половина бюджета была израсходована к полудню,
# что составляет 20 долларов.
# Оставшийся бюджет после полудня составил 40 - 20 = 20.
# 80%  оставшегося бюджета было потрачено между полуднем и временем закрытия. Это 80% от 20 долларов, что равно 0,8 * 20 = 16.
#
# Таким образом, остаток бюджета составил 20 - 16 = 4.
#
# **Ответ:** 4 $

# %% [markdown]
# **2)**
#
# Сначала найдем расходы одной кампании в течение одного часа работы:
#
# 120 долларов / (5 кампаний * 24 дня * 6 часов) = 1/6 доллара в час для одной кампании.
#
# Теперь давайте рассмотрим, сколько дней 9 одинаковых кампаний будут работать по 8 часов в день, чтобы потратить 216 долларов:
#
# * Расходы одной кампании за один час равны 1/6 доллара.
#
# * За 8 часов одна кампания потратит 8 * 1/6 доллара = 4/3 доллара в день.
#
# * Для 9 кампаний за один день тратится 9 * 4/3 доллара = 12 долларов.
#
# Теперь мы знаем, что 9 кампаний потратят 12 доллара за один день. Для того, чтобы потратить 216 долларов им потребуется:
#
# 216 долларов / 12 доллара в день = 18 дней.
#
# **Ответ:** 18 дней

# %% [markdown]
# **3)**
#
# * 200 - 80 = 120 – столько всего баннеров было использовано рекламными компаниями.
# * Из них 60 - только компания 1. Значит, остальные 60 - это сумма: только компания 2 плюс некоторое число общих баннеров.
# * Известно, что на 1 общий баннер приходится 3 таких, которые использовала только компания 2.
# * первых (общих) должно быть 15, а вторых – 45.
#
# Таким образом, получаем:
# только 1 компания – 60 баннеров,
# только 2 компания – 45, общие – 15.
#
# **Ответ**: 15

# %% [markdown]
# **4)**
#
# |  | insta | facebook | youtube |
# | --- | --- | --- | --- |
# | Энн | + | - | + |
# | Джон | - | + | + |
# | Кейт | - | + | + |
# | Том | + | + | - |
#
# Если каждый использует две соц.сети, то совпадают Джон и Кейт
#
# **Ответ:** Джон и Кейт

# %% [markdown]
# **5)**
# Средний балл = (Сумма баллов по всем модулям) / (Количество модулей)
#
# Мы знаем, что средний балл по 4 модулям составляет 78 баллов:
#
# 78 = (Сумма баллов по 4 модулям) / 4
#
# Теперь мы хотим, чтобы средний балл после 5-го модуля был 80. Пусть X будет баллом за 5-й модуль:
#
# 80 = (Сумма баллов по всем модулям, включая 5-й модуль) / 5
#
# Теперь мы можем решить эту систему уравнений для X:
#
# 78 = (Сумма баллов по 4 модулям) / 4
# 80 = (Сумма баллов по всем модулям, включая 5-й модуль) / 5
# Сначала выразим сумму баллов по 4 модулям из первого уравнения:
#
# Сумма баллов по 4 модулям = 78 * 4 = 312 баллов
#
# Теперь, используя это значение, выразим сумму баллов по всем модулям, включая 5-й модуль, из второго уравнения:
#
# 80 = (Сумма баллов по всем модулям, включая 5-й модуль) / 5
#
# Сумма баллов по всем модулям, включая 5-й модуль = 80 * 5 = 400 баллов
#
# Теперь нам нужно выяснить, сколько баллов стажер уже набрал по первым 4 модулям (312 баллов), и сколько ему нужно получить за 5-й модуль, чтобы сумма стала равной 400 баллов:
#
# Баллы за 5-й модуль = Сумма баллов по всем модулям, включая 5-й модуль - Сумма баллов по первым 4 модулям
# Баллы за 5-й модуль = 400 - 312 = 88 баллов
#
# Итак, стажер должен получить 88 баллов за 5-й модуль, чтобы средний балл по всему заданию составил 80.
#
# **Ответ:** 88

# %%
80 * 5 - 4 * 78
# Out:
# 88

# %% [markdown]
# **6)**
#
# t1 = 260/80 = 3 часа 15 минут = 195 мин
#
# t2 = 260/100 = 2 часа 36 минут = 156 мин
#
# 195 - 156 = 39 мин
#
# **Ответ:** 39 мин

# %% [markdown]
# ## **Техническое задание**

# %% [markdown]
# Вопросы:
#
#
# *   Вычислите общую выручку за июль 2021 по тем сделкам, приход денежных средств которых не просрочен.
# *   Как изменялась выручка компании за рассматриваемый период? Проиллюстрируйте графиком.
# * Кто из менеджеров привлек для компании больше всего денежных средств в сентябре 2021?
# * Какой тип сделок (новая/текущая) был преобладающим в октябре 2021?
# * Сколько оригиналов договора по майским сделкам было получено в июне 2021?

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#      client_id      sum      status        sale new/current  Unnamed: 5  \
# 0          NaN      NaN    Май 2021         NaN         NaN         NaN
# 1          6.0  11693.7  ВНУТРЕННИЙ           -           -         NaN
# 2         14.0   5452.7    ОПЛАЧЕНО     Петрова       новая         NaN
# 3         15.0  13991.7    ОПЛАЧЕНО      Иванов     текущая         NaN
# 4         16.0    719.7    ОПЛАЧЕНО      Иванов     текущая         NaN
# ..         ...      ...         ...         ...         ...         ...
# 725      285.0   4328.7    ОПЛАЧЕНО    Васильев     текущая         NaN
# 726      360.0   3096.2    ОПЛАЧЕНО    Васильев       новая         NaN
# 727      360.0   3096.2  ПРОСРОЧЕНО    Васильев       новая         NaN
# 728      373.0   4403.7    ОПЛАЧЕНО    Михайлов       новая         NaN
# 729      286.0   3978.7    ОПЛАЧЕНО  Филимонова     текущая         NaN
#
#      document       receiving_date
# 0         NaN                  NaN
# ...

# %%
df.dtypes
# Out:
# client_id         float64
# sum               float64
# status             object
# sale               object
# new/current        object
# Unnamed: 5        float64
# document           object
# receiving_date     object
# dtype: object

# %%
df.isna().sum()
# Out:
# client_id           6
# sum                 6
# status              0
# sale                6
# new/current         6
# Unnamed: 5        730
# document           21
# receiving_date    123
# dtype: int64

# %%
#удалим колонку Unnamed:5, так как она полностью пуста

df.drop(columns=['Unnamed: 5'],inplace=True)
df
# Out:
#      client_id      sum      status        sale new/current  document  \
# 0          NaN      NaN    Май 2021         NaN         NaN       NaN
# 1          6.0  11693.7  ВНУТРЕННИЙ           -           -         -
# 2         14.0   5452.7    ОПЛАЧЕНО     Петрова       новая  оригинал
# 3         15.0  13991.7    ОПЛАЧЕНО      Иванов     текущая  оригинал
# 4         16.0    719.7    ОПЛАЧЕНО      Иванов     текущая  оригинал
# ..         ...      ...         ...         ...         ...       ...
# 725      285.0   4328.7    ОПЛАЧЕНО    Васильев     текущая  оригинал
# 726      360.0   3096.2    ОПЛАЧЕНО    Васильев       новая       НЕТ
# 727      360.0   3096.2  ПРОСРОЧЕНО    Васильев       новая       НЕТ
# 728      373.0   4403.7    ОПЛАЧЕНО    Михайлов       новая  оригинал
# 729      286.0   3978.7    ОПЛАЧЕНО  Филимонова     текущая  оригинал
#
#           receiving_date
# 0                    NaN
# 1                      -
# 2    2021-07-26 00:00:00
# ...

# %%
df.status.value_counts()
# Out:
# ОПЛАЧЕНО         622
# ПРОСРОЧЕНО        52
# В РАБОТЕ          44
# НА ПОДПИСАНИИ      5
# Май 2021           1
# ВНУТРЕННИЙ         1
# Июнь 2021          1
# Июль 2021          1
# Август 2021        1
# Сентябрь 2021      1
# Октябрь 2021       1
# Name: status, dtype: int64

# %%
def date(d):
    res = []
    for x in d:
        if isinstance(x, datetime):
            res.append(x)
        else:
            res.append(np.nan)
    return res


def month(d):
    res = []
    for x in d:
        try:
            res.append(x.month)
        except:
            res.append(np.nan)
    return res



def year(d):
    res = []
    for x in d:
        try:
            res.append(x.year)
        except:
            res.append(np.nan)
    return res


df.receiving_date = date(df.receiving_date)
df['receiving_month'] = month(df.receiving_date)
df['receiving_year'] = year(df.receiving_date)

# %% [markdown]
# Вычислите общую выручку за июль 2021 по тем сделкам, приход денежных средств которых не просрочен.

# %%
df.query('status != "ПРОСРОЧЕНО" & receiving_month==7 & receiving_year==2021')\
 ['sum'].sum()
# Out:
# 757830.7399999996

# %% [markdown]
# Как изменялась выручка компании за рассматриваемый период? Проиллюстрируйте графиком.

# %%
data_by_date = df.groupby('receiving_date')['sum'].sum().reset_index()

# Вычисление скользящей суммы с окном 30 дней
rolling_sum = data_by_date['sum'].rolling(window=30).sum()


plt.figure(figsize = (12, 6))
sns.lineplot(x = 'receiving_date', y=rolling_sum, data=data_by_date)
plt.title('Изменение выручки по дням с 30-дневной скользящей суммой')
plt.xlabel('Дата')
plt.ylabel('Скользящая сумма')
plt.xticks(rotation = 45)

plt.show()

# %%
# Группировка данных по 'receiving_month' и агрегация суммы
data_by_month = df.groupby('receiving_month')['sum'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='receiving_month', y='sum', data=data_by_month)
plt.title('Сумма по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Сумма')
plt.show()

# %% [markdown]
# Видим, что общая динамика - положительная. Выручка растет.
# На графике по месяцам просадка на 11 месяц, поскольку данные только до середины месяца.

# %% [markdown]
# Кто из менеджеров привлек для компании больше всего денежных средств в сентябре 2021?

# %%
filtered_data = df[df['receiving_month'] == 9]

sale_sum = filtered_data.groupby('sale')['sum'].sum().reset_index()

sale_sum = sale_sum.sort_values(by='sum', ascending=False)

print(sale_sum)
# Out:
#          sale        sum
# 4     Петрова  219240.12
# 2      Иванов  165314.80
# 5     Смирнов  155245.90
# 0     Андреев  124714.55
# 3   Кузнецова   60230.20
# 1    Васильев   55667.50
# 7  Филимонова   45763.30
# 6     Соколов   44234.60

# %% [markdown]
# Менеджер Петрова привлекла больше всего денежных средств в сентябре 2021

# %% [markdown]
# Какой тип сделок (новая/текущая) был преобладающим в октябре 2021?

# %%
filtered_data = df[df['receiving_month'] == 10]

deal_type_count = filtered_data.groupby('new/current')['document'].count().reset_index()

deal_type_count = deal_type_count.rename(columns={'document': 'count'})

deal_type_count
# Out:
#   new/current  count
# 0       новая     16
# 1     текущая    101

# %% [markdown]
# В октябре 2021 преобладали сделки с типом текущая

# %% [markdown]
# Сколько оригиналов договора по майским сделкам было получено в июне 2021?

# %%
print('Число оригиналов договора по майским сделкам было получено в июне 2021 равно', df.query('document == "оригинал" & receiving_month == 6').shape[0])
# Out:
# Число оригиналов договора по майским сделкам было получено в июне 2021 равно 76

# %% [markdown]
# Задание:
#
# За каждую заключенную сделку менеджер получает бонус, который рассчитывается следующим образом.
# * За новые сделки менеджер получает 7 % от суммы, при условии, что статус оплаты «ОПЛАЧЕНО», а также имеется оригинал подписанного договора с клиентом (в рассматриваемом месяце).
# * За текущие сделки менеджер получает 5 % от суммы, если она больше 10 тыс., и 3 % от суммы, если меньше. При этом статус оплаты может быть любым, кроме «ПРОСРОЧЕНО», а также необходимо наличие оригинала подписанного договора с клиентом (в рассматриваемом месяце).
#
# Бонусы по сделкам, оригиналы для которых приходят позже рассматриваемого месяца, считаются остатком на следующий период, который выплачивается по мере прихода оригиналов. Вычислите остаток каждого из менеджеров на 01.07.2021.

# %%
def get_bonus(row):
    # Коэффициенты для бонусов
    coef_max = 0.07
    coef_middle = 0.05
    coef_min = 0.03

    # Проверка условий для новых клиентов
    if row['new/current'] == 'новая' and row['status'] == 'ОПЛАЧЕНО' and row['receiving_date']:
        return round(row['sum'] * coef_max, 2)

    # Проверка условий для текущих клиентов
    if row['new/current'] == 'текущая':
        if row['status'] != 'ПРОСРОЧЕНО':
            if row['sum'] < 10000:
                return round(row['sum'] * coef_min, 2)
            else:
                return round(row['sum'] * coef_middle, 2)

    return 0

df['bonus'] = df.apply(get_bonus, axis=1)
df
# Out:
#      client_id      sum      status        sale new/current  document  \
# 0          NaN      NaN    Май 2021         NaN         NaN       NaN
# 1          6.0  11693.7  ВНУТРЕННИЙ           -           -         -
# 2         14.0   5452.7    ОПЛАЧЕНО     Петрова       новая  оригинал
# 3         15.0  13991.7    ОПЛАЧЕНО      Иванов     текущая  оригинал
# 4         16.0    719.7    ОПЛАЧЕНО      Иванов     текущая  оригинал
# ..         ...      ...         ...         ...         ...       ...
# 725      285.0   4328.7    ОПЛАЧЕНО    Васильев     текущая  оригинал
# 726      360.0   3096.2    ОПЛАЧЕНО    Васильев       новая       НЕТ
# 727      360.0   3096.2  ПРОСРОЧЕНО    Васильев       новая       НЕТ
# 728      373.0   4403.7    ОПЛАЧЕНО    Михайлов       новая  оригинал
# 729      286.0   3978.7    ОПЛАЧЕНО  Филимонова     текущая  оригинал
#
#     receiving_date  receiving_month  receiving_year   bonus
# 0              NaT              NaN             NaN    0.00
# ...

# %%
filtered_data = df[df['receiving_date'] > '2021-07-01']

# Группировка данных по 'sale' и агрегация суммы 'sales_bonus'
result = filtered_data.groupby('sale')['bonus'].sum().reset_index()

# Вывод результата
print(result)
# Out:
#          sale     bonus
# 0     Андреев  27164.33
# 1    Васильев   6934.62
# 2      Иванов  22041.63
# 3   Кузнецова  16108.75
# 4    Михайлов    607.07
# 5     Петрова  28282.41
# 6   Селиванов   7102.47
# 7     Смирнов  31089.65
# 8     Соколов   3730.70
# 9  Филимонова  11043.56
